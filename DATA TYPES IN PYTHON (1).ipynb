# %% [markdown]
# **DATA TYPES IN PYTHON

# %%
name ='arifa'

# %%
print(name)
# Out:
# arifa

# %%
type(name)
# Out:
# str

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
name ='11'
print(name)      #if inside qoutes it will consider as string
# Out:
# 11

# %%
name="22"

# %%
print (name)
# Out:
# 22

# %%
name="""22"""

# %%
print (name)
# Out:
# 22

# %%
name='''22'''

# %%
print(name)
# Out:
# 22

# %%
name = """aaaaaaabbbbbbbbccccccc
          dddddeeeeeefffffgggggg
          hhhhhhhhh"""                #for printing multiple lines

# %%
print(name)
# Out:
# aaaaaaabbbbbbbbccccccc
#           dddddeeeeeefffffgggggg
#           hhhhhhhhh

# %% [markdown]
# data type
# COMPLEX

# %%
age=90+5j

# %%
print(type(age))
# Out:
# <class 'complex'>

# %%
print(age.real)
# Out:
# 90.0

# %%
print(age.imag)
# Out:
# 5.0

# %% [markdown]
# SQUENCE TYPE**(COLLECTION OF DATA)**
#  List,tuple,range
#   MAPPING TYPES
#
#   dict(collection of data)

# %%
dict={name:'arifa',age:20}

# %% [markdown]
# **set types**
#  1;set
#  2;frozen set
#
# # BOOLEAN DATA TYPES
# # TRUE
# # FALSE

# %%
x=True

# %%
print(type(x))
# Out:
# <class 'bool'>

# %%
print(True+True)
# Out:
# 2

# %%
print(True+False)
# Out:
# 1

# %%
print(True+False+True)
# Out:
# 2

# %% [markdown]
# NONE TYPE

# %%
x=None
print(x)
# Out:
# None

# %%
print(type(x))
# Out:
# <class 'NoneType'>

# %% [markdown]
# # DATA TYPE CASTING

# %%
age=20

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
age=str(age)

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
print(age)
# Out:
# 20

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age=float(age)

# %%
print(type(age))
# Out:
# <class 'float'>

# %%
print(age)
# Out:
# 20.0

# %%
age=complex(age)

# %%
print(age)
# Out:
# (20+0j)

# %%
age.imag
# Out:
# 0.0

# %%
print(type(age))
# Out:
# <class 'complex'>
