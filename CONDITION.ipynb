# %%
#user input

# User

age = 20

age = int(input('enter your age : '))


float = float(input('enter your age : '))

print(float)

print(type(float))

print(age)

print(type(age))
# Out:
# enter your age : 21
# enter your age : 29
# 29.0
# <class 'float'>
# 21
# <class 'int'>

# %% [markdown]
# conditions are used to design the path of exicution

# %%
a = 40
b = 30

if a > b:
    print('a is greater than b')
elif a == b:
    print('a is equal to b')
else:
    print('a is less than b')
# Out:
# a is greater than b

# %%
a = 20
b =25
c =15

if a > b:
  print('a is greater than b')
elif a > c:
  print('a is greater than c')
elif a < c:
  print ('a is less than c')
elif b >c:
  print('b is greater than c')
else:
  print('b is less than c')
# Out:
# a is greater than c

# %%
   x = int(input('enter your age : '))
   y = int(input('enter your age : '))

   if x <= y :
       print( 'x is eligible for vote')
   elif x ==y :
      print('y is eligible for vote')
   else:
      print('x and y are note eligible for vote')
# Out:
# enter your age : 25
# enter your age : 30
# x is eligible for vote

# %%
age = int(input('enter your age : '))

if age <10:
    print('lp')
elif age <13:
    print('up')
elif age <15:
  print('high school')
elif age <18:
  print('hs')
else:
  print('invalid')
# Out:
# enter your age : 20
# invalid

# %%
age = int(input ('enter your name'))
health = input('enter your health condition 1 for critical,2 for normal')
if age <50 and health =="1" :
  print('eligible for CPR')
elif age <50 and health =="2":
  print('you are not eligible for CPR')
elif age >50 and health == "1":
  print('eligible for CPR')
elif age >50 and health == "1":
  print('you are not eligible for CPR')
else:
    print('invalid')
# Out:
# enter your name45
# enter your health condition 1 for critical,2 for normal2
# you are not eligible for CPR
